# %% [markdown]
# # Snake (Tabular Q-Learning)
# Train a tabular Q-learning agent for a Snake-like game.
#
# **Tip:** run Pygame UI locally and upload a short YouTube demo.

# %%
# !pip -q install numpy matplotlib

# %%
# Upload snake_qlearning.py to this Colab session, then run:
from snake_qlearning import train, parse_args
args = parse_args()
args.episodes = 3000
args.out_dir = 'artifacts'
train(args)
